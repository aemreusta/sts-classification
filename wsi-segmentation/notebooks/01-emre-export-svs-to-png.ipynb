# %%
# !apt update && apt install -y openslide-tools
# !pip install openslide-python
# !pip install shapely

# %%
from google.colab import drive

# Mount the Google Drive to access the files
drive.mount("/content/gdrive/")

# %%
# Set the working directory
work_directory = r"/Volumes/T7 Red/wsi_segmentation/"

# %%
import os
import sys
import openslide
from tqdm.auto import tqdm
from shapely.geometry import shape
import json

# Add the path to your project root directory
if work_directory not in sys.path:
    sys.path.append(work_directory)

# my utility functions
from utils.general import read_path, create_directory
from utils.drawing_functions import draw_segmentation_mask, annotate_images

# %%
DATASETS_PATH = os.path.join(work_directory, "datasets")
INTERIM_PATH = os.path.join(DATASETS_PATH, "interim")
CP_RAW_PATH = os.path.join("/Volumes/T7 Red/cerrahpasa-wsi", "raw")
CP_ANNOTATIONS_PATH = os.path.join("/Volumes/T7 Red/cerrahpasa-wsi", "annotations")
RAW_PATH = os.path.join("/Volumes/T7 Red/wsi_code/datasets", "raw")
ANNOTATIONS_PATH = os.path.join("/Volumes/T7 Red/wsi_code/datasets", "annotations")

# %%
slides = read_path(os.path.join(RAW_PATH, "**/*.svs"), recursive=True)
slides.extend(read_path(os.path.join(CP_RAW_PATH, "**/*.svs"), recursive=True))
slides.sort()
annotations = read_path(os.path.join(ANNOTATIONS_PATH, "**/*.geojson"), recursive=True)
annotations.extend(
    read_path(os.path.join(CP_ANNOTATIONS_PATH, "**/*.geojson"), recursive=True)
)
annotations.sort()

# %%
print(len(slides), slides[:5])
print(len(annotations), annotations[:5])
# Out:
# 56 ['/Volumes/T7 Red/cerrahpasa-wsi/raw/lms/B-1088-2022-1 YD-YK.svs', '/Volumes/T7 Red/cerrahpasa-wsi/raw/lms/B-1088-2022-2 YD-YK.svs', '/Volumes/T7 Red/cerrahpasa-wsi/raw/lms/B-1088-2022-4 YD-YK.svs', '/Volumes/T7 Red/cerrahpasa-wsi/raw/lms/B-1586-21-1 YK.svs', '/Volumes/T7 Red/cerrahpasa-wsi/raw/lms/B-1586-21-11-YK-YD.svs']
# 56 ['/Volumes/T7 Red/cerrahpasa-wsi/annotations/lms_co/B-1088-2022-1 YD-YK.geojson', '/Volumes/T7 Red/cerrahpasa-wsi/annotations/lms_co/B-1088-2022-2 YD-YK.geojson', '/Volumes/T7 Red/cerrahpasa-wsi/annotations/lms_co/B-1088-2022-4 YD-YK.geojson', '/Volumes/T7 Red/cerrahpasa-wsi/annotations/lms_co/B-1586-21-1 YK.geojson', '/Volumes/T7 Red/cerrahpasa-wsi/annotations/lms_co/B-1586-21-11-YK-YD.geojson']

# %%
X1_EXTRACT_PATH = os.path.join(INTERIM_PATH, "x64")
X1_MASKS_EXTRACT_PATH = os.path.join(INTERIM_PATH, "x64_masks")
X1_THUMB_EXTRACT_PATH = os.path.join(INTERIM_PATH, "x64_thumbs")
X4_EXTRACT_PATH = os.path.join(INTERIM_PATH, "x16")
X4_MASKS_EXTRACT_PATH = os.path.join(INTERIM_PATH, "x16_masks")

create_directory(X1_EXTRACT_PATH)
create_directory(X1_MASKS_EXTRACT_PATH)
create_directory(X1_THUMB_EXTRACT_PATH)
create_directory(X4_EXTRACT_PATH)
create_directory(X4_MASKS_EXTRACT_PATH)
# Out:
# Directory already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64
# Directory already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks
# Directory already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs
# Directory already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16
# Directory already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks

# %%
def process_slide(slide, annotations):
    slide_name = os.path.splitext(os.path.basename(slide))[0]
    case_name = slide.split("/")[-2]
    print(f"Processing slide: {slide_name} from case: {case_name}")

    # Read the annotations
    with open(annotations, "r") as json_file:
        geojson_data = json.load(json_file)

    geojson_polygons = [
        shape(feature["geometry"]) for feature in geojson_data["features"]
    ]

    json_file.close()

    # Read the slide
    sld = openslide.OpenSlide(slide)
    # print_slide_info(sld)

    # Extract the x1 and x4 images
    scale_x1 = sld.level_downsamples[-1]
    scale_x4 = sld.level_downsamples[-2]

    for scale in [scale_x1, scale_x4]:
        if scale == scale_x1:
            level = sld.level_count - 1
        elif scale == scale_x4:
            level = sld.level_count - 2

        rgb_slide = sld.read_region((0, 0), level, sld.level_dimensions[level])
        seg_mask = draw_segmentation_mask(rgb_slide.size, geojson_polygons, scale)
        rgb_slide = rgb_slide.convert("RGB")

        output_dir = X1_EXTRACT_PATH if scale == scale_x1 else X4_EXTRACT_PATH
        mask_output_dir = (
            X1_MASKS_EXTRACT_PATH if scale == scale_x1 else X4_MASKS_EXTRACT_PATH
        )

        output_path = os.path.join(output_dir, f"{slide_name}_x{int(scale)}.png")
        mask_output_path = os.path.join(
            mask_output_dir, f"{slide_name}_x{int(scale)}_mask.png"
        )
        thumb_output_path = os.path.join(
            X1_THUMB_EXTRACT_PATH, f"{slide_name}_x{int(scale)}_thumb.png"
        )

        if not os.path.exists(output_path):
            rgb_slide.save(output_path, "PNG")
            print(f"Saved image: {output_path}")
        else:
            print(f"Image already exists: {output_path}")

        if not os.path.exists(mask_output_path):
            seg_mask.save(mask_output_path, "PNG")
            print(f"Saved mask: {mask_output_path}")
        else:
            print(f"Mask already exists: {mask_output_path}")

        if not os.path.exists(thumb_output_path) and scale == scale_x1:
            thumb = annotate_images(
                rgb_slide, geojson_polygons, scale, fill_color=(0, 255, 0, 51)
            )
            thumb.save(thumb_output_path, "PNG")
            print(f"Saved thumb: {thumb_output_path}")
        else:
            print(f"Thumb already exists: {thumb_output_path}")

    sld.close()

# %%
# Loop through slides and annotations
for slide, anno in tqdm(zip(slides, annotations), total=len(slides)):
    process_slide(slide, anno)
# Out:
#   0%|          | 0/56 [00:00<?, ?it/s]
# Processing slide: B-1088-2022-1 YD-YK from case: lms
# Image already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-1088-2022-1 YD-YK_x64.png
# Mask already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-1088-2022-1 YD-YK_x64_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-1088-2022-1 YD-YK_x64_thumb.png
# Image already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-1088-2022-1 YD-YK_x16.png
# Mask already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-1088-2022-1 YD-YK_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-1088-2022-1 YD-YK_x16_thumb.png
# Processing slide: B-1088-2022-2 YD-YK from case: lms
# Image already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-1088-2022-2 YD-YK_x64.png
# Mask already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-1088-2022-2 YD-YK_x64_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-1088-2022-2 YD-YK_x64_thumb.png
# Image already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-1088-2022-2 YD-YK_x16.png
# Mask already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-1088-2022-2 YD-YK_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-1088-2022-2 YD-YK_x16_thumb.png
# Processing slide: B-1088-2022-4 YD-YK from case: lms
# Image already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-1088-2022-4 YD-YK_x64.png
# Mask already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-1088-2022-4 YD-YK_x64_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-1088-2022-4 YD-YK_x64_thumb.png
# Image already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-1088-2022-4 YD-YK_x16.png
# Mask already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-1088-2022-4 YD-YK_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-1088-2022-4 YD-YK_x16_thumb.png
# Processing slide: B-1586-21-1 YK from case: lms
# Image already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-1586-21-1 YK_x64.png
# Mask already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-1586-21-1 YK_x64_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-1586-21-1 YK_x64_thumb.png
# Image already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-1586-21-1 YK_x16.png
# Mask already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-1586-21-1 YK_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-1586-21-1 YK_x16_thumb.png
# Processing slide: B-1586-21-11-YK-YD from case: lms
# Image already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-1586-21-11-YK-YD_x64.png
# Mask already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-1586-21-11-YK-YD_x64_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-1586-21-11-YK-YD_x64_thumb.png
# Image already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-1586-21-11-YK-YD_x16.png
# Mask already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-1586-21-11-YK-YD_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-1586-21-11-YK-YD_x16_thumb.png
# Processing slide: B-1586-21-22 from case: lms
# Image already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-1586-21-22_x64.png
# Mask already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-1586-21-22_x64_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-1586-21-22_x64_thumb.png
# Image already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-1586-21-22_x16.png
# Mask already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-1586-21-22_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-1586-21-22_x16_thumb.png
# Processing slide: B-1586-21-23 from case: lms
# Image already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-1586-21-23_x64.png
# Mask already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-1586-21-23_x64_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-1586-21-23_x64_thumb.png
# Image already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-1586-21-23_x16.png
# Mask already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-1586-21-23_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-1586-21-23_x16_thumb.png
# Processing slide: B-1586-21-25 from case: lms
# Image already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-1586-21-25_x64.png
# Mask already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-1586-21-25_x64_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-1586-21-25_x64_thumb.png
# Image already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-1586-21-25_x16.png
# Mask already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-1586-21-25_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-1586-21-25_x16_thumb.png
# Processing slide: B-1586-21-4- YK-YD from case: lms
# Image already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-1586-21-4- YK-YD_x64.png
# Mask already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-1586-21-4- YK-YD_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-1586-21-4- YK-YD_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-1586-21-4- YK-YD_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-1586-21-4- YK-YD_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-1586-21-4- YK-YD_x16_thumb.png
# Processing slide: B-1586-21-6-YK-YD from case: lms
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-1586-21-6-YK-YD_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-1586-21-6-YK-YD_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-1586-21-6-YK-YD_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-1586-21-6-YK-YD_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-1586-21-6-YK-YD_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-1586-21-6-YK-YD_x16_thumb.png
# Processing slide: B-822-2022-15 YD from case: lms
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-822-2022-15 YD_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-822-2022-15 YD_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-822-2022-15 YD_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-822-2022-15 YD_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-822-2022-15 YD_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-822-2022-15 YD_x16_thumb.png
# Processing slide: B-822-2022-44-YD from case: lms
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-822-2022-44-YD_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-822-2022-44-YD_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-822-2022-44-YD_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-822-2022-44-YD_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-822-2022-44-YD_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-822-2022-44-YD_x16_thumb.png
# Processing slide: B-998-2021-4-SOLUNUM from case: lms
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-998-2021-4-SOLUNUM_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-998-2021-4-SOLUNUM_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-998-2021-4-SOLUNUM_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-998-2021-4-SOLUNUM_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-998-2021-4-SOLUNUM_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-998-2021-4-SOLUNUM_x16_thumb.png
# Processing slide: B-356-2016-3 from case: mpskt
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-356-2016-3_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-356-2016-3_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-356-2016-3_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-356-2016-3_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-356-2016-3_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-356-2016-3_x16_thumb.png
# Processing slide: B-356-2016-4 from case: mpskt
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-356-2016-4_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-356-2016-4_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-356-2016-4_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-356-2016-4_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-356-2016-4_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-356-2016-4_x16_thumb.png
# Processing slide: B-356-2016-5 from case: mpskt
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-356-2016-5_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-356-2016-5_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-356-2016-5_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-356-2016-5_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-356-2016-5_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-356-2016-5_x16_thumb.png
# Processing slide: B-5640-2018-T3 from case: mpskt
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-5640-2018-T3_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-5640-2018-T3_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-5640-2018-T3_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-5640-2018-T3_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-5640-2018-T3_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-5640-2018-T3_x16_thumb.png
# Processing slide: B-5640-2018-T4 from case: mpskt
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-5640-2018-T4_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-5640-2018-T4_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-5640-2018-T4_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-5640-2018-T4_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-5640-2018-T4_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-5640-2018-T4_x16_thumb.png
# Processing slide: B-7743-2016-2 from case: mpskt
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-7743-2016-2_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-7743-2016-2_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-7743-2016-2_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-7743-2016-2_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-7743-2016-2_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-7743-2016-2_x16_thumb.png
# Processing slide: B-7743-2016-4 from case: mpskt
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-7743-2016-4_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-7743-2016-4_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-7743-2016-4_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-7743-2016-4_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-7743-2016-4_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-7743-2016-4_x16_thumb.png
# Processing slide: B-7743-2016-8 from case: mpskt
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-7743-2016-8_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-7743-2016-8_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-7743-2016-8_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-7743-2016-8_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-7743-2016-8_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-7743-2016-8_x16_thumb.png
# Processing slide: B-8256-2022-3 from case: mpskt
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-8256-2022-3_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-8256-2022-3_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-8256-2022-3_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-8256-2022-3_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-8256-2022-3_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-8256-2022-3_x16_thumb.png
# Processing slide: B-8815-2022-14 from case: mpskt
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-8815-2022-14_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-8815-2022-14_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-8815-2022-14_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-8815-2022-14_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-8815-2022-14_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-8815-2022-14_x16_thumb.png
# Processing slide: B-8815-2022-20 from case: mpskt
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-8815-2022-20_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-8815-2022-20_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-8815-2022-20_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-8815-2022-20_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-8815-2022-20_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-8815-2022-20_x16_thumb.png
# Processing slide: B-8815-2022-21 from case: mpskt
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-8815-2022-21_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-8815-2022-21_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-8815-2022-21_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-8815-2022-21_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-8815-2022-21_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-8815-2022-21_x16_thumb.png
# Processing slide: B-8815-2022-22 from case: mpskt
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-8815-2022-22_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-8815-2022-22_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-8815-2022-22_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-8815-2022-22_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-8815-2022-22_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-8815-2022-22_x16_thumb.png
# Processing slide: B-1372-2022-19 from case: ss
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-1372-2022-19_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-1372-2022-19_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-1372-2022-19_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-1372-2022-19_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-1372-2022-19_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-1372-2022-19_x16_thumb.png
# Processing slide: B-615-2020-11-YD-DS-TEK PARCA  from case: ss
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-615-2020-11-YD-DS-TEK PARCA _x32.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-615-2020-11-YD-DS-TEK PARCA _x32_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-615-2020-11-YD-DS-TEK PARCA _x32_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-615-2020-11-YD-DS-TEK PARCA _x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-615-2020-11-YD-DS-TEK PARCA _x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-615-2020-11-YD-DS-TEK PARCA _x16_thumb.png
# Processing slide: B-615-2020-11-YD-DS from case: ss
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-615-2020-11-YD-DS_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-615-2020-11-YD-DS_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-615-2020-11-YD-DS_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-615-2020-11-YD-DS_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-615-2020-11-YD-DS_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-615-2020-11-YD-DS_x16_thumb.png
# Processing slide: B-615-2020-12 from case: ss
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-615-2020-12_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-615-2020-12_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-615-2020-12_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-615-2020-12_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-615-2020-12_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-615-2020-12_x16_thumb.png
# Processing slide: B-615-2020-14 from case: ss
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-615-2020-14_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-615-2020-14_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-615-2020-14_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-615-2020-14_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-615-2020-14_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-615-2020-14_x16_thumb.png
# Processing slide: B-615-2020-15 from case: ss
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-615-2020-15_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-615-2020-15_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-615-2020-15_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-615-2020-15_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-615-2020-15_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-615-2020-15_x16_thumb.png
# Processing slide: B-615-2020-5 from case: ss
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-615-2020-5_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-615-2020-5_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-615-2020-5_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-615-2020-5_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-615-2020-5_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-615-2020-5_x16_thumb.png
# Processing slide: B-615-2020-7 from case: ss
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-615-2020-7_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-615-2020-7_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-615-2020-7_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-615-2020-7_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-615-2020-7_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-615-2020-7_x16_thumb.png
# Processing slide: B-615-2020-8 from case: ss
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-615-2020-8_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-615-2020-8_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-615-2020-8_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-615-2020-8_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-615-2020-8_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-615-2020-8_x16_thumb.png
# Processing slide: B-615-2020-9 from case: ss
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/B-615-2020-9_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/B-615-2020-9_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-615-2020-9_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/B-615-2020-9_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/B-615-2020-9_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/B-615-2020-9_x16_thumb.png
# Processing slide: TCGA-3B-A9HI-01Z-00-DX1.FF553011-934A-4E3E-AA53-B87FC307E095 from case: liposarkom
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/TCGA-3B-A9HI-01Z-00-DX1.FF553011-934A-4E3E-AA53-B87FC307E095_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/TCGA-3B-A9HI-01Z-00-DX1.FF553011-934A-4E3E-AA53-B87FC307E095_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-3B-A9HI-01Z-00-DX1.FF553011-934A-4E3E-AA53-B87FC307E095_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/TCGA-3B-A9HI-01Z-00-DX1.FF553011-934A-4E3E-AA53-B87FC307E095_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/TCGA-3B-A9HI-01Z-00-DX1.FF553011-934A-4E3E-AA53-B87FC307E095_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-3B-A9HI-01Z-00-DX1.FF553011-934A-4E3E-AA53-B87FC307E095_x16_thumb.png
# Processing slide: TCGA-DX-AB36-01Z-00-DX2.B0293A74-52AC-490B-A5F0-CA96F4B36252 from case: liposarkom
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/TCGA-DX-AB36-01Z-00-DX2.B0293A74-52AC-490B-A5F0-CA96F4B36252_x32.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/TCGA-DX-AB36-01Z-00-DX2.B0293A74-52AC-490B-A5F0-CA96F4B36252_x32_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-DX-AB36-01Z-00-DX2.B0293A74-52AC-490B-A5F0-CA96F4B36252_x32_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/TCGA-DX-AB36-01Z-00-DX2.B0293A74-52AC-490B-A5F0-CA96F4B36252_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/TCGA-DX-AB36-01Z-00-DX2.B0293A74-52AC-490B-A5F0-CA96F4B36252_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-DX-AB36-01Z-00-DX2.B0293A74-52AC-490B-A5F0-CA96F4B36252_x16_thumb.png
# Processing slide: TCGA-DX-AB37-01Z-00-DX1.B778136D-9699-48FA-91F2-16BD16569571 from case: liposarkom
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/TCGA-DX-AB37-01Z-00-DX1.B778136D-9699-48FA-91F2-16BD16569571_x32.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/TCGA-DX-AB37-01Z-00-DX1.B778136D-9699-48FA-91F2-16BD16569571_x32_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-DX-AB37-01Z-00-DX1.B778136D-9699-48FA-91F2-16BD16569571_x32_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/TCGA-DX-AB37-01Z-00-DX1.B778136D-9699-48FA-91F2-16BD16569571_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/TCGA-DX-AB37-01Z-00-DX1.B778136D-9699-48FA-91F2-16BD16569571_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-DX-AB37-01Z-00-DX1.B778136D-9699-48FA-91F2-16BD16569571_x16_thumb.png
# Processing slide: TCGA-DX-AB37-01Z-00-DX3.AE53E163-C3F2-4BF1-8A2E-232842C590F1 from case: liposarkom
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/TCGA-DX-AB37-01Z-00-DX3.AE53E163-C3F2-4BF1-8A2E-232842C590F1_x32.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/TCGA-DX-AB37-01Z-00-DX3.AE53E163-C3F2-4BF1-8A2E-232842C590F1_x32_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-DX-AB37-01Z-00-DX3.AE53E163-C3F2-4BF1-8A2E-232842C590F1_x32_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/TCGA-DX-AB37-01Z-00-DX3.AE53E163-C3F2-4BF1-8A2E-232842C590F1_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/TCGA-DX-AB37-01Z-00-DX3.AE53E163-C3F2-4BF1-8A2E-232842C590F1_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-DX-AB37-01Z-00-DX3.AE53E163-C3F2-4BF1-8A2E-232842C590F1_x16_thumb.png
# Processing slide: TCGA-Z4-A9VC-01Z-00-DX1.42D1CACE-2FFB-4CE4-B8D6-8C0D5BC3B3F2 from case: liposarkom
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/TCGA-Z4-A9VC-01Z-00-DX1.42D1CACE-2FFB-4CE4-B8D6-8C0D5BC3B3F2_x32.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/TCGA-Z4-A9VC-01Z-00-DX1.42D1CACE-2FFB-4CE4-B8D6-8C0D5BC3B3F2_x32_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-Z4-A9VC-01Z-00-DX1.42D1CACE-2FFB-4CE4-B8D6-8C0D5BC3B3F2_x32_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/TCGA-Z4-A9VC-01Z-00-DX1.42D1CACE-2FFB-4CE4-B8D6-8C0D5BC3B3F2_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/TCGA-Z4-A9VC-01Z-00-DX1.42D1CACE-2FFB-4CE4-B8D6-8C0D5BC3B3F2_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-Z4-A9VC-01Z-00-DX1.42D1CACE-2FFB-4CE4-B8D6-8C0D5BC3B3F2_x16_thumb.png
# Processing slide: TCGA-DX-A3U7-01Z-00-DX1.FD7076CA-39BC-4330-B91C-6DF7F0751D57 from case: lms
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/TCGA-DX-A3U7-01Z-00-DX1.FD7076CA-39BC-4330-B91C-6DF7F0751D57_x32.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/TCGA-DX-A3U7-01Z-00-DX1.FD7076CA-39BC-4330-B91C-6DF7F0751D57_x32_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-DX-A3U7-01Z-00-DX1.FD7076CA-39BC-4330-B91C-6DF7F0751D57_x32_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/TCGA-DX-A3U7-01Z-00-DX1.FD7076CA-39BC-4330-B91C-6DF7F0751D57_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/TCGA-DX-A3U7-01Z-00-DX1.FD7076CA-39BC-4330-B91C-6DF7F0751D57_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-DX-A3U7-01Z-00-DX1.FD7076CA-39BC-4330-B91C-6DF7F0751D57_x16_thumb.png
# Processing slide: TCGA-DX-A48L-01Z-00-DX1.656CE0A0-F442-4715-8250-C7B71A73FBCC from case: lms
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/TCGA-DX-A48L-01Z-00-DX1.656CE0A0-F442-4715-8250-C7B71A73FBCC_x32.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/TCGA-DX-A48L-01Z-00-DX1.656CE0A0-F442-4715-8250-C7B71A73FBCC_x32_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-DX-A48L-01Z-00-DX1.656CE0A0-F442-4715-8250-C7B71A73FBCC_x32_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/TCGA-DX-A48L-01Z-00-DX1.656CE0A0-F442-4715-8250-C7B71A73FBCC_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/TCGA-DX-A48L-01Z-00-DX1.656CE0A0-F442-4715-8250-C7B71A73FBCC_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-DX-A48L-01Z-00-DX1.656CE0A0-F442-4715-8250-C7B71A73FBCC_x16_thumb.png
# Processing slide: TCGA-IF-A4AK-01Z-00-DX1.A39253B8-4899-4360-BFF2-3538AEF7A970 from case: lms
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/TCGA-IF-A4AK-01Z-00-DX1.A39253B8-4899-4360-BFF2-3538AEF7A970_x32.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/TCGA-IF-A4AK-01Z-00-DX1.A39253B8-4899-4360-BFF2-3538AEF7A970_x32_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-IF-A4AK-01Z-00-DX1.A39253B8-4899-4360-BFF2-3538AEF7A970_x32_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/TCGA-IF-A4AK-01Z-00-DX1.A39253B8-4899-4360-BFF2-3538AEF7A970_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/TCGA-IF-A4AK-01Z-00-DX1.A39253B8-4899-4360-BFF2-3538AEF7A970_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-IF-A4AK-01Z-00-DX1.A39253B8-4899-4360-BFF2-3538AEF7A970_x16_thumb.png
# Processing slide: TCGA-X6-A7WC-01Z-00-DX1.A1B72EE7-D7BD-4D23-A38F-39CC4E1C32A8 from case: lms
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/TCGA-X6-A7WC-01Z-00-DX1.A1B72EE7-D7BD-4D23-A38F-39CC4E1C32A8_x64.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/TCGA-X6-A7WC-01Z-00-DX1.A1B72EE7-D7BD-4D23-A38F-39CC4E1C32A8_x64_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-X6-A7WC-01Z-00-DX1.A1B72EE7-D7BD-4D23-A38F-39CC4E1C32A8_x64_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/TCGA-X6-A7WC-01Z-00-DX1.A1B72EE7-D7BD-4D23-A38F-39CC4E1C32A8_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/TCGA-X6-A7WC-01Z-00-DX1.A1B72EE7-D7BD-4D23-A38F-39CC4E1C32A8_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-X6-A7WC-01Z-00-DX1.A1B72EE7-D7BD-4D23-A38F-39CC4E1C32A8_x16_thumb.png
# Processing slide: TCGA-X6-A7WD-01Z-00-DX2.37790492-072A-4392-8D7B-904286F6C805 from case: lms
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/TCGA-X6-A7WD-01Z-00-DX2.37790492-072A-4392-8D7B-904286F6C805_x32.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/TCGA-X6-A7WD-01Z-00-DX2.37790492-072A-4392-8D7B-904286F6C805_x32_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-X6-A7WD-01Z-00-DX2.37790492-072A-4392-8D7B-904286F6C805_x32_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/TCGA-X6-A7WD-01Z-00-DX2.37790492-072A-4392-8D7B-904286F6C805_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/TCGA-X6-A7WD-01Z-00-DX2.37790492-072A-4392-8D7B-904286F6C805_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-X6-A7WD-01Z-00-DX2.37790492-072A-4392-8D7B-904286F6C805_x16_thumb.png
# Processing slide: TCGA-QQ-A8VG-01Z-00-DX1.A9A10DBA-09AE-4C1A-A126-2180536400ED from case: mpskt
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/TCGA-QQ-A8VG-01Z-00-DX1.A9A10DBA-09AE-4C1A-A126-2180536400ED_x32.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/TCGA-QQ-A8VG-01Z-00-DX1.A9A10DBA-09AE-4C1A-A126-2180536400ED_x32_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-QQ-A8VG-01Z-00-DX1.A9A10DBA-09AE-4C1A-A126-2180536400ED_x32_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/TCGA-QQ-A8VG-01Z-00-DX1.A9A10DBA-09AE-4C1A-A126-2180536400ED_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/TCGA-QQ-A8VG-01Z-00-DX1.A9A10DBA-09AE-4C1A-A126-2180536400ED_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-QQ-A8VG-01Z-00-DX1.A9A10DBA-09AE-4C1A-A126-2180536400ED_x16_thumb.png
# Processing slide: TCGA-QQ-A8VG-01Z-00-DX2.9C8082B3-7E59-46C8-88B6-73DD4D2D29E7 from case: mpskt
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/TCGA-QQ-A8VG-01Z-00-DX2.9C8082B3-7E59-46C8-88B6-73DD4D2D29E7_x32.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/TCGA-QQ-A8VG-01Z-00-DX2.9C8082B3-7E59-46C8-88B6-73DD4D2D29E7_x32_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-QQ-A8VG-01Z-00-DX2.9C8082B3-7E59-46C8-88B6-73DD4D2D29E7_x32_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/TCGA-QQ-A8VG-01Z-00-DX2.9C8082B3-7E59-46C8-88B6-73DD4D2D29E7_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/TCGA-QQ-A8VG-01Z-00-DX2.9C8082B3-7E59-46C8-88B6-73DD4D2D29E7_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-QQ-A8VG-01Z-00-DX2.9C8082B3-7E59-46C8-88B6-73DD4D2D29E7_x16_thumb.png
# Processing slide: TCGA-RN-AAAQ-01Z-00-DX1.493F5285-F6E5-435F-902F-E384E4440C53 from case: mpskt
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/TCGA-RN-AAAQ-01Z-00-DX1.493F5285-F6E5-435F-902F-E384E4440C53_x32.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/TCGA-RN-AAAQ-01Z-00-DX1.493F5285-F6E5-435F-902F-E384E4440C53_x32_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-RN-AAAQ-01Z-00-DX1.493F5285-F6E5-435F-902F-E384E4440C53_x32_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/TCGA-RN-AAAQ-01Z-00-DX1.493F5285-F6E5-435F-902F-E384E4440C53_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/TCGA-RN-AAAQ-01Z-00-DX1.493F5285-F6E5-435F-902F-E384E4440C53_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-RN-AAAQ-01Z-00-DX1.493F5285-F6E5-435F-902F-E384E4440C53_x16_thumb.png
# Processing slide: TCGA-SI-A71O-01Z-00-DX5.DAF40BD0-4B92-4201-8B03-B0BFAA14CBBC from case: mpskt
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/TCGA-SI-A71O-01Z-00-DX5.DAF40BD0-4B92-4201-8B03-B0BFAA14CBBC_x32.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/TCGA-SI-A71O-01Z-00-DX5.DAF40BD0-4B92-4201-8B03-B0BFAA14CBBC_x32_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-SI-A71O-01Z-00-DX5.DAF40BD0-4B92-4201-8B03-B0BFAA14CBBC_x32_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/TCGA-SI-A71O-01Z-00-DX5.DAF40BD0-4B92-4201-8B03-B0BFAA14CBBC_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/TCGA-SI-A71O-01Z-00-DX5.DAF40BD0-4B92-4201-8B03-B0BFAA14CBBC_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-SI-A71O-01Z-00-DX5.DAF40BD0-4B92-4201-8B03-B0BFAA14CBBC_x16_thumb.png
# Processing slide: TCGA-SI-A71Q-01Z-00-DX3.746B592F-98CD-41CA-837E-E4E0B12F4020 from case: mpskt
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/TCGA-SI-A71Q-01Z-00-DX3.746B592F-98CD-41CA-837E-E4E0B12F4020_x32.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/TCGA-SI-A71Q-01Z-00-DX3.746B592F-98CD-41CA-837E-E4E0B12F4020_x32_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-SI-A71Q-01Z-00-DX3.746B592F-98CD-41CA-837E-E4E0B12F4020_x32_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/TCGA-SI-A71Q-01Z-00-DX3.746B592F-98CD-41CA-837E-E4E0B12F4020_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/TCGA-SI-A71Q-01Z-00-DX3.746B592F-98CD-41CA-837E-E4E0B12F4020_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-SI-A71Q-01Z-00-DX3.746B592F-98CD-41CA-837E-E4E0B12F4020_x16_thumb.png
# Processing slide: TCGA-DX-A7EQ-01Z-00-DX1.6E243B4A-CE79-4B31-B98B-24B89E7C2FB4 from case: ss
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/TCGA-DX-A7EQ-01Z-00-DX1.6E243B4A-CE79-4B31-B98B-24B89E7C2FB4_x32.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/TCGA-DX-A7EQ-01Z-00-DX1.6E243B4A-CE79-4B31-B98B-24B89E7C2FB4_x32_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-DX-A7EQ-01Z-00-DX1.6E243B4A-CE79-4B31-B98B-24B89E7C2FB4_x32_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/TCGA-DX-A7EQ-01Z-00-DX1.6E243B4A-CE79-4B31-B98B-24B89E7C2FB4_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/TCGA-DX-A7EQ-01Z-00-DX1.6E243B4A-CE79-4B31-B98B-24B89E7C2FB4_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-DX-A7EQ-01Z-00-DX1.6E243B4A-CE79-4B31-B98B-24B89E7C2FB4_x16_thumb.png
# Processing slide: TCGA-DX-AB3B-01Z-00-DX1.454F6EDB-796F-4BB0-A92E-E4F5D592E897 from case: ss
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/TCGA-DX-AB3B-01Z-00-DX1.454F6EDB-796F-4BB0-A92E-E4F5D592E897_x32.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/TCGA-DX-AB3B-01Z-00-DX1.454F6EDB-796F-4BB0-A92E-E4F5D592E897_x32_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-DX-AB3B-01Z-00-DX1.454F6EDB-796F-4BB0-A92E-E4F5D592E897_x32_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/TCGA-DX-AB3B-01Z-00-DX1.454F6EDB-796F-4BB0-A92E-E4F5D592E897_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/TCGA-DX-AB3B-01Z-00-DX1.454F6EDB-796F-4BB0-A92E-E4F5D592E897_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-DX-AB3B-01Z-00-DX1.454F6EDB-796F-4BB0-A92E-E4F5D592E897_x16_thumb.png
# Processing slide: TCGA-DX-AB3B-01Z-00-DX2.2BC397E2-2F44-4C2D-87C2-439A052C8B0F from case: ss
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/TCGA-DX-AB3B-01Z-00-DX2.2BC397E2-2F44-4C2D-87C2-439A052C8B0F_x32.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/TCGA-DX-AB3B-01Z-00-DX2.2BC397E2-2F44-4C2D-87C2-439A052C8B0F_x32_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-DX-AB3B-01Z-00-DX2.2BC397E2-2F44-4C2D-87C2-439A052C8B0F_x32_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/TCGA-DX-AB3B-01Z-00-DX2.2BC397E2-2F44-4C2D-87C2-439A052C8B0F_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/TCGA-DX-AB3B-01Z-00-DX2.2BC397E2-2F44-4C2D-87C2-439A052C8B0F_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-DX-AB3B-01Z-00-DX2.2BC397E2-2F44-4C2D-87C2-439A052C8B0F_x16_thumb.png
# Processing slide: TCGA-DX-AB3C-01Z-00-DX2.CBA90EC0-A148-400F-9DFA-870F637E2958 from case: ss
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/TCGA-DX-AB3C-01Z-00-DX2.CBA90EC0-A148-400F-9DFA-870F637E2958_x32.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/TCGA-DX-AB3C-01Z-00-DX2.CBA90EC0-A148-400F-9DFA-870F637E2958_x32_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-DX-AB3C-01Z-00-DX2.CBA90EC0-A148-400F-9DFA-870F637E2958_x32_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/TCGA-DX-AB3C-01Z-00-DX2.CBA90EC0-A148-400F-9DFA-870F637E2958_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/TCGA-DX-AB3C-01Z-00-DX2.CBA90EC0-A148-400F-9DFA-870F637E2958_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-DX-AB3C-01Z-00-DX2.CBA90EC0-A148-400F-9DFA-870F637E2958_x16_thumb.png
# Processing slide: TCGA-MJ-A850-01Z-00-DX1.67DDD01B-0D67-4A0F-B535-B9A1E1BE65EA from case: ss
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64/TCGA-MJ-A850-01Z-00-DX1.67DDD01B-0D67-4A0F-B535-B9A1E1BE65EA_x32.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_masks/TCGA-MJ-A850-01Z-00-DX1.67DDD01B-0D67-4A0F-B535-B9A1E1BE65EA_x32_mask.png
# Saved thumb: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-MJ-A850-01Z-00-DX1.67DDD01B-0D67-4A0F-B535-B9A1E1BE65EA_x32_thumb.png
# Saved image: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16/TCGA-MJ-A850-01Z-00-DX1.67DDD01B-0D67-4A0F-B535-B9A1E1BE65EA_x16.png
# Saved mask: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x16_masks/TCGA-MJ-A850-01Z-00-DX1.67DDD01B-0D67-4A0F-B535-B9A1E1BE65EA_x16_mask.png
# Thumb already exists: /Volumes/T7 Red/wsi_segmentation/datasets/interim/x64_thumbs/TCGA-MJ-A850-01Z-00-DX1.67DDD01B-0D67-4A0F-B535-B9A1E1BE65EA_x16_thumb.png
